# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

data = np.loadtxt("water216_nve_1ps_1e-5_0.25fs.log", usecols=(0, 3))
steps = data[:, 0]
ene = (data[:, 1] - np.mean(data[:, 1])) * 23.0605


plt.plot(steps, ene)
